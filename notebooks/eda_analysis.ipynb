# %% [markdown]
# # 1. Introduction to the Dataset

# %% [markdown]
# ### 1.1 Dateset Overview

# %% [markdown]
# ##### Purpose: The dataset comprises historical delivery records, aiming to predict Delivery_Time based on various operational and environmental factors.

# %% [markdown]
# ##### Key Features: Order_ID, Agent_Age, Agent_Rating, Store_Latitude, Store_Longitude, Drop_Longitude, Order_date, Order_Time, Pickup_Time, Weather, Traffic, Vehicles, Area, Category, and the target variable, Delivery_Time.

# %% [markdown]
# ### 1.2 Data Types

# %% [markdown]
# #####  unique identifier:  Order_ID

# %% [markdown]
# ##### Numerical:  Agent_Age, Agent_Rating, Store_Latitude, Store_Longitude, Drop_Longitude, Delivery_Time

# %% [markdown]
# ##### Categorical:  Order_date, Order_Time, Pickup_Time (datetime/time-based); Weather, Traffic, Vehicles, Area, Category

# %% [markdown]
# # 2. Univariate Analysis

# %% [markdown]
# ### 2.1. Target Variable Analysis: Delivery_Time 🚚

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/Users/anuragchaubey/RouteWise/data/processed/delivery_data_cleaned.csv")

# %% [markdown]
# ##### --- 1. Descriptive Statistics ---

# %%
print("Descriptive Statistics for Delivery_Time:")
print(df['Delivery_Time'].describe())
print("\n")
# Out:
# Descriptive Statistics for Delivery_Time:
# count    43594.000000
# mean       124.916433
# std         51.941975
# min         10.000000
# 25%         90.000000
# 50%        125.000000
# 75%        160.000000
# max        270.000000
# Name: Delivery_Time, dtype: float64

# %% [markdown]
# ##### --- 2. Histogram/Distribution Plot ---

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Delivery_Time'], kde=True, bins=15, color='skyblue')
plt.title('Distribution of Delivery Time', fontsize=16)
plt.xlabel('Delivery Time (minutes)', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ##### --- 3. Box Plot ---

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(y=df['Delivery_Time'], color='lightcoral')
plt.title('Box Plot of Delivery Time', fontsize=16)
plt.ylabel('Delivery Time (minutes)', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# <div style="font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif; background-color: #ffffff; color: #333333; padding: 20px; line-height: 1.8; border-radius: 8px; box-shadow: 0 2px 6px rgba(0,0,0,0.05); margin-top: 30px; border: 2px solid #6cb4f0;">
#
#   <p style="font-size: 18px; font-weight: 600; color: #2c3e50; margin-bottom: 10px;">📦 <u>Distribution:</u></p>
#   <ul style="font-size: 16px; padding-left: 20px;">
#     <li>Most delivery times fall between <b>50 and 200 minutes</b>.</li>
#     <li>The distribution is <b>right-skewed</b>, suggesting a tail of longer delivery durations.</li>
#   </ul>
#
#   <p style="font-size: 18px; font-weight: 600; color: #2c3e50; margin-bottom: 10px;">⚠️ <u>Outlier Detection:</u></p>
#   <ul style="font-size: 16px; padding-left: 20px;">
#     <li>A significant outlier exists above <b>250 minutes</b>, as shown in the box plot.</li>
#     <li>This could indicate:
#       <ul style="margin-top: 5px; padding-left: 20px; list-style-type: square;">
#         <li>A rare/extreme real-world delivery delay,</li>
#         <li>A data entry error, or</li>
#         <li>A delivery in unusual circumstances.</li>
#       </ul>
#     </li>
#   </ul>
#
#   <p style="font-size: 18px; font-weight: 600; color: #2c3e50; margin-bottom: 10px;">💡 <u>Insight:</u></p>
#   <p style="font-size: 16px;">
#     The typical delivery time range is <b>efficient (50–200 mins)</b>, but the outlier(s) can affect model performance if not handled.<br>
#     Important to investigate and consider preprocessing (e.g., <b>capping, transformation, or removal</b>).
#   </p>
#
# </div>

# %% [markdown]
# ### 2.2 Numerical Features Analysis

# %% [markdown]
# <h3 style="color:#007bff;">Agent_Age Analysis</h3>

# %%
print("Descriptive Statistics for Agent_Age:")
print(df['Agent_Age'].describe())
print("\n")

# --- Histogram/Distribution Plot for Agent_Age ---
plt.figure(figsize=(10, 6))
sns.histplot(df['Agent_Age'], kde=True, bins=10, color='lightgreen')
plt.title('Distribution of Agent Age', fontsize=16)
plt.xlabel('Agent Age (Years)', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()


# --- Box Plot for Agent_Age ---
plt.figure(figsize=(8, 5))
sns.boxplot(y=df['Agent_Age'], color='lightcoral')
plt.title('Box Plot of Agent Age', fontsize=16)
plt.ylabel('Agent Age (Years)', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# Descriptive Statistics for Agent_Age:
# count    43594.000000
# mean        29.555719
# std          5.760689
# min         20.000000
# 25%         25.000000
# 50%         30.000000
# 75%         35.000000
# max         39.000000
# Name: Agent_Age, dtype: float64

# %% [markdown]
# <div style="background-color: #ffffff; color: #2c3e50; font-family: 'Segoe UI', Tahoma, sans-serif; border: 2px solid #4aa3df; border-radius: 8px; padding: 20px; line-height: 1.7; font-size: 16px;">
#
#   <h4 style="color: #1d3557;">📊 Distribution:</h4>
#   <ul>
#     <li>Most agent ages lie between <strong>20 and 40 years</strong>.</li>
#     <li>The frequency across this range is fairly <strong>uniform</strong>, with around <strong>4500 agents</strong> per age group.</li>
#     <li>There are <strong>no outliers</strong>, and the distribution appears <strong>symmetric and balanced</strong>.</li>
#   </ul>
#
#   <h4 style="color: #1d3557;">💡 Insight:</h4>
#   <ul>
#     <li>The agent workforce is predominantly <strong>young</strong> and <strong>evenly distributed</strong> in age between 20 and 40 years.</li>
#     <li>The absence of outliers suggests <strong>consistency</strong> in age-based recruitment or workforce planning.</li>
#     <li>Since age is <strong>uniformly spread</strong> and has <strong>no anomalies</strong>, it’s a <strong>stable feature</strong> for modeling and does not require transformation or outlier treatment.</li>
#   </ul>
#
# </div>

# %% [markdown]
# <h3 style="color:#007bff;">Agent_Rating Analysis</h3>

# %%
print("Descriptive Statistics for Agent_Rating:")
print(df['Agent_Rating'].describe())

plt.figure(figsize=(10, 6))
sns.histplot(df['Agent_Rating'], kde=True, bins=5, color='orange') # Adjust bins for rating scale
plt.title('Distribution of Agent Rating', fontsize=16)
plt.xlabel('Agent Rating', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()


plt.figure(figsize=(8, 5))
sns.boxplot(y=df['Agent_Rating'], color='lightblue')
plt.title('Box Plot of Agent Rating', fontsize=16)
plt.ylabel('Agent Rating', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# Descriptive Statistics for Agent_Rating:
# count    43594.000000
# mean         4.635287
# std          0.313827
# min          2.500000
# 25%          4.500000
# 50%          4.700000
# 75%          4.900000
# max          5.000000
# Name: Agent_Rating, dtype: float64

# %% [markdown]
# <div style="background-color: #ffffff; color: #2c3e50; font-family: 'Segoe UI', Tahoma, sans-serif; border: 2px solid #4aa3df; border-radius: 8px; padding: 20px; line-height: 1.7; font-size: 16px;">
#
#   <h4 style="color: #1d3557;">📊 Distribution:</h4>
#   <ul>
#     <li>The distribution is <strong>left-skewed</strong>, with most agents rated between <strong>4.5 and 5.0</strong>.</li>
#     <li>A large number of agents have ratings <strong>clustered near the maximum</strong> value of 5.0, indicating high performance across the board.</li>
#   </ul>
#
#   <h4 style="color: #1d3557;">⚠️ Outliers:</h4>
#   <ul>
#     <li>The box plot reveals a few outliers with ratings <strong>below 4.0</strong>, including values as low as <strong>2.5</strong>.</li>
#     <li>These may represent:
#       <ul>
#         <li><em>Underperforming agents</em></li>
#         <li><em>Rare cases of low customer satisfaction</em></li>
#       </ul>
#     </li>
#   </ul>
#
#   <h4 style="color: #1d3557;">💡 Insight:</h4>
#   <ul>
#     <li>Agents are generally rated <strong>very highly</strong>, with a mean of <strong>4.63</strong> and a maximum of <strong>5.0</strong>.</li>
#     <li>The small standard deviation (<strong>0.31</strong>) indicates <em>low variation</em> in performance.</li>
#     <li>The few low ratings may require <strong>further investigation</strong> or <strong>training intervention</strong> to maintain overall quality standards.</li>
#   </ul>
#
# </div>

# %% [markdown]
# <h3 style="color:#007bff;">Store_Latitude Analysis</h3>

# %%
print("Descriptive Statistics for Store_Latitude:")
print(df['Store_Latitude'].describe())

plt.figure(figsize=(10, 6))
sns.histplot(df['Store_Latitude'], kde=True, bins=20, color='purple')
plt.title('Distribution of Store Latitude', fontsize=16)
plt.xlabel('Store Latitude', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

plt.figure(figsize=(8, 5))
sns.boxplot(y=df['Store_Latitude'], color='violet')
plt.title('Box Plot of Store Latitude', fontsize=16)
plt.ylabel('Store Latitude', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# Descriptive Statistics for Store_Latitude:
# count    43594.000000
# mean        17.244769
# std          7.690005
# min        -30.902872
# 25%         12.933298
# 50%         18.554382
# 75%         22.732225
# max         30.914057
# Name: Store_Latitude, dtype: float64

# %% [markdown]
# <h4>Distribution:</h4>
# <ul>
#   <li>Most store latitudes are concentrated between <strong>10° and 30°</strong>.</li>
#   <li>The histogram reveals <strong>multiple peaks (multi-modal)</strong>, suggesting stores are located in <em>distinct geographic zones</em>.</li>
#   <li>A noticeable cluster around <strong>0° (equator)</strong> indicates some stores might be in equatorial regions.</li>
# </ul>
#
# <h4>Outliers:</h4>
# <ul>
#   <li>The box plot shows outliers with latitudes <strong>below 0°</strong>, including values as low as <strong>-30.90</strong>.</li>
#   <li>These may indicate:
#     <ul>
#       <li><em>Stores in the southern hemisphere</em>.</li>
#       <li><em>Incorrect or misrecorded coordinates</em>.</li>
#     </ul>
#   </li>
# </ul>
#
# <h4>Insight:</h4>
# <ul>
#   <li>The latitude values are mostly within an <strong>expected geographic range</strong>.</li>
#   <li>However, the presence of negative values suggests either <em>legitimate southern hemisphere locations</em> or <em>potential data quality issues</em>.</li>
#   <li>These outliers should be <strong>verified</strong>: if erroneous, they should be <em>cleaned</em>; if valid, they indicate <strong>broader geographic coverage</strong>.</li>
# </ul>

# %% [markdown]
# <h3 style="color:#007bff;">Store_Longitude Analysis</h3>

# %%
print("Descriptive Statistics for Store_Longitude:")
print(df['Store_Longitude'].describe())

plt.figure(figsize=(10, 6))
sns.histplot(df['Store_Longitude'], kde=True, bins=20, color='purple')
plt.title('Distribution of Store Longitude', fontsize=16)
plt.xlabel('Store Longitude', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

plt.figure(figsize=(8, 5))
sns.boxplot(y=df['Store_Longitude'], color='violet')
plt.title('Box Plot of Store Longitude', fontsize=16)
plt.ylabel('Store Longitude', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# Descriptive Statistics for Store_Longitude:
# count    43594.000000
# mean        70.768898
# std         21.128773
# min          0.000000
# 25%         73.170283
# 50%         75.898497
# 75%         78.045359
# max         88.433452
# Name: Store_Longitude, dtype: float64

# %% [markdown]
# <h4>Distribution:</h4>
# <ul>
#   <li>Most store longitudes are clustered between <strong>73° and 78°</strong>, suggesting a concentration in a specific longitudinal band.</li>
#   <li>The <strong>mean (70.77)</strong> is slightly lower than the <strong>median (75.90)</strong>, indicating a <em>left-skewed distribution</em> due to some lower values.</li>
#   <li>The <strong>minimum value is 0</strong>, which is geographically unusual and might represent <em>missing or incorrect data</em>.</li>
# </ul>
#
# <h4>Outliers:</h4>
# <ul>
#   <li>A few values near <strong>0</strong> are present, which are unlikely to correspond to real-world store locations.</li>
#   <li>These are likely <em>data entry errors</em> or <em>missing coordinate values</em> improperly encoded as 0.</li>
# </ul>
#
# <h4>Insight:</h4>
# <ul>
#   <li>The majority of stores are within a narrow, realistic geographic range, indicating <strong>accurate location data</strong> for most entries.</li>
#   <li>Values like <strong>0 longitude</strong> should be <em>flagged for validation or cleaning</em> to avoid distortion in spatial or mapping analyses.</li>
# </ul>

# %% [markdown]
# <h3 style="color:#007bff;">Drop_Latitude Analysis</h3>

# %%
print("Descriptive Statistics for Drop_Latitude:")
print(df['Drop_Latitude'].describe())

plt.figure(figsize=(10, 6))
sns.histplot(df['Drop_Latitude'], kde=True, bins=20, color='purple')
plt.title('Distribution of Drop Latitude', fontsize=16)
plt.xlabel('Drop Latitude', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

plt.figure(figsize=(8, 5))
sns.boxplot(y=df['Drop_Latitude'], color='violet')
plt.title('Box Plot of Drop Latitude', fontsize=16)
plt.ylabel('Drop Latitude', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# Descriptive Statistics for Drop_Latitude:
# count    43594.000000
# mean        17.461540
# std          7.338199
# min          0.010000
# 25%         12.986054
# 50%         18.633934
# 75%         22.785049
# max         31.054057
# Name: Drop_Latitude, dtype: float64

# %% [markdown]
# <h4>Distribution:</h4>
# <ul>
#   <li><strong>Median (18.63)</strong> is slightly higher than <strong>Mean (17.46)</strong>, indicating a slight <em>left skew</em>.</li>
#   <li>Most values lie between <strong>13° and 23° latitude</strong>, which aligns with locations in <strong>southern and central India</strong>.</li>
#   <li>The <strong>standard deviation (7.34)</strong> suggests a moderate spread but still within a reasonable geographic range.</li>
# </ul>
#
# <h4>Outliers:</h4>
# <ul>
#   <li>The <strong>minimum value (0.01)</strong> is suspicious and unrealistic for any Indian location.</li>
#   <li>This likely represents <em>missing or incorrectly recorded coordinates</em>.</li>
# </ul>
#
# <h4>Insight:</h4>
# <ul>
#   <li>The majority of <strong>Drop_Latitude</strong> values are valid and geographically consistent.</li>
#   <li>However, entries close to <strong>0</strong> may be <em>placeholders or data errors</em> and should be <em>cleaned or handled separately</em> before performing spatial or route analysis.</li>
# </ul>

# %% [markdown]
# <h3 style="color:#007bff;">Drop_Longitude Analysis</h3>

# %%
print("Descriptive Statistics for Drop_Longitude:")
print(df['Drop_Longitude'].describe())

plt.figure(figsize=(10, 6))
sns.histplot(df['Drop_Longitude'], kde=True, bins=20, color='purple')
plt.title('Distribution of Drop Longitude', fontsize=16)
plt.xlabel('Drop Longitude', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

plt.figure(figsize=(8, 5))
sns.boxplot(y=df['Drop_Longitude'], color='violet')
plt.title('Box Plot of Drop Longitude', fontsize=16)
plt.ylabel('Drop Longitude', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# Descriptive Statistics for Drop_Longitude:
# count    43594.000000
# mean        70.832489
# std         21.128940
# min          0.010000
# 25%         73.280000
# 50%         76.002471
# 75%         78.102309
# max         88.563452
# Name: Drop_Longitude, dtype: float64

# %% [markdown]
# <h4>Distribution:</h4>
# <ul>
#   <li><strong>Median (76.00)</strong> is greater than <strong>Mean (70.83)</strong>, indicating a <em>left-skewed distribution</em> due to some lower longitude values.</li>
#   <li>Most drop locations fall between <strong>73°E and 78°E</strong>, matching areas like <strong>Maharashtra, Karnataka, Telangana, and Andhra Pradesh</strong>.</li>
# </ul>
#
# <h4>Outliers:</h4>
# <ul>
#   <li><strong>Minimum value (0.01)</strong> is unrealistic for India and far below the expected range.</li>
#   <li>This may indicate <em>missing or misrecorded entries</em> that need cleaning.</li>
#   <li>Very low longitude values are likely <em>placeholders or entry errors</em>.</li>
# </ul>
#
# <h4>Insight:</h4>
# <ul>
#   <li>Most <strong>Drop_Longitude</strong> values are valid and within a realistic Indian range.</li>
#   <li>Outlier values (especially <strong>&lt; 65</strong> or near <strong>0</strong>) should be <em>cleaned or imputed</em> to ensure reliable spatial analysis.</li>
# </ul>

# %% [markdown]
# ### 2.3. Categorical Features Analysis

# %% [markdown]
# <h3 style="color:#007bff;">Weather Analysis</h3>

# %%
df['Weather'].describe()
# Out:
# count     43594
# unique        6
# top         Fog
# freq       7435
# Name: Weather, dtype: object

# %%
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='Weather', order=df['Weather'].value_counts().index, hue='Weather', palette='pastel', legend=False)
plt.title('Weather Condition Distribution', fontsize=14)
plt.xlabel('Weather')
plt.ylabel('Count')
plt.xticks(rotation=15)
plt.tight_layout()
plt.show()

# %% [markdown]
# <h4>📊 Description:</h4>
# <ul>
#   <li><strong>Total entries:</strong> 43,594</li>
#   <li><strong>Unique categories:</strong> 6 (<code>Fog</code>, <code>Stormy</code>, <code>Cloudy</code>, <code>Sandstorms</code>, <code>Windy</code>, <code>Sunny</code>)</li>
#   <li><strong>Most frequent category:</strong> <code>Fog</code> (7,435 times)</li>
#   <li><strong>Least frequent category:</strong> <code>Sunny</code> (around 7,045 times)</li>
# </ul>
#
# <h4>📈 Visualization:</h4>
# <p>The bar plot shows that all weather conditions appear with <strong>very similar frequency</strong>, ranging from ~7,000 to ~7,400. This indicates the data is <strong>balanced</strong> for weather-related conditions.</p>
#
# <h4>💡 Insight:</h4>
# <ul>
#   <li><strong>Balanced distribution:</strong> No weather condition dominates the dataset.</li>
#   <li><strong>No rare category:</strong> Since each has a similar count, no special handling is required due to class imbalance.</li>
# </ul>

# %% [markdown]
# <h3 style="color:#007bff;">Traffic Analysis</h3>

# %%
# Traffic summary
print(df['Traffic'].describe())
print(df['Traffic'].value_counts())

# Traffic visualization
sns.countplot(data=df, x='Traffic', order=df['Traffic'].value_counts().index)
plt.title('Traffic Density Distribution')
plt.xlabel('Traffic')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# count     43594
# unique        4
# top        Low
# freq      14976
# Name: Traffic, dtype: object
# Traffic
# Low        14976
# Jam        13710
# Medium     10614
# High        4294
# Name: count, dtype: int64

# %% [markdown]
# <h4>Distribution:</h4>
# <ul>
#   <li><strong>Total Entries:</strong> 43,594</li>
#   <li><strong>Unique Categories:</strong> 4 (Low, Jam, Medium, High)</li>
#   <li><strong>Most Frequent Category:</strong> <strong>Low</strong> traffic with <strong>14,976</strong> entries</li>
#   <li>Followed by:
#     <ul>
#       <li><strong>Jam:</strong> 13,710 entries</li>
#       <li><strong>Medium:</strong> 10,614 entries</li>
#       <li><strong>High:</strong> 4,294 entries</li>
#     </ul>
#   </li>
# </ul>
#
# <h4>Insight:</h4>
# <ul>
#   <li><strong>Low</strong> and <strong>Jam</strong> traffic conditions are the most common, together forming a majority of the records.</li>
#   <li><strong>High</strong> traffic is relatively rare, which might indicate specific times or areas with intense congestion.</li>
#   <li>These distributions suggest a possible <em>imbalance</em> that could affect model training—consider encoding strategies like <strong>frequency encoding</strong> or using <strong>SMOTE</strong> if used as a target.</li>
# </ul>
#
# <h4>Considerations:</h4>
# <ul>
#   <li>If predicting delivery delays, <strong>High</strong> traffic might play a significant role and should be given attention during feature engineering.</li>
#   <li>Ensure that spelling and casing (e.g., "Low ", "low") are <strong>standardized</strong> to avoid duplicates in categories.</li>
# </ul>

# %% [markdown]
# <h3 style="color:#007bff;">Vehicle Analysis</h3>

# %%
# Create a new DataFrame for plotting
vehicle_df = df['Vehicle'].value_counts().reset_index()
vehicle_df.columns = ['Vehicle_Type', 'Count']
total = len(df)

plt.figure(figsize=(8, 5))
ax = sns.barplot(data=vehicle_df, x='Vehicle_Type', y='Count', hue='Vehicle_Type', palette='viridis', legend=False)

# Add percentages on top
for i, count in enumerate(vehicle_df['Count']):
    percent = count / total * 100
    ax.text(i, count + 200, f'{percent:.1f}%', ha='center')

plt.title('Vehicle Type Distribution (with %)')
plt.xlabel('Vehicle Type')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %% [markdown]
# <h4>Distribution:</h4>
# <ul>
#   <li><strong>Motorcycles</strong> are the most common vehicle type, making up approximately <strong>58.5%</strong> of the total.</li>
#   <li><strong>Scooters</strong> are the second most frequent, contributing about <strong>33.5%</strong>.</li>
#   <li><strong>Vans</strong> are the least common, accounting for just <strong>8.0%</strong>.</li>
# </ul>
#
# <h4>Insight:</h4>
# <ul>
#   <li>The high share of <strong>motorcycles and scooters</strong> suggests a predominance of two-wheelers in delivery operations.</li>
#   <li>This may be due to their <em>cost-effectiveness, fuel efficiency, and ease of navigation</em> in urban traffic.</li>
#   <li><strong>Vans</strong> might be used for <em>bulk deliveries or longer routes</em>, given their smaller representation.</li>
# </ul>
#
# <h4>Recommendation:</h4>
# <ul>
#   <li>For route optimization or delivery time analysis, consider <strong>vehicle type</strong> as an influencing factor—two-wheelers may behave differently than vans.</li>
# </ul>

# %% [markdown]
# <h3 style="color:#007bff;">Area Analysis</h3>

# %%
print("Value Counts for Area:\n")
print(df['Area'].value_counts())

# Count plot for Area
# Prepare DataFrame for plotting
area_df = df['Area'].value_counts().reset_index()
area_df.columns = ['Area', 'Count']
total = len(df)

plt.figure(figsize=(8, 5))
ax = sns.barplot(data=area_df, x='Area', y='Count', hue='Area', palette='Set2', legend=False)

# Add percentages on top
for i, count in enumerate(area_df['Count']):
    percent = count / total * 100
    ax.text(i, count + 200, f'{percent:.1f}%', ha='center')

plt.title('Delivery Area Distribution (with %)')
plt.xlabel('Area')
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# Value Counts for Area:
#
# Area
# Metropolitian     32592
# Urban              9715
# Other              1135
# Semi-Urban          152
# Name: count, dtype: int64

# %% [markdown]
# <table border="1" cellpadding="5" cellspacing="0">
#   <thead>
#     <tr>
#       <th>Area</th>
#       <th>Count</th>
#       <th>Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Metropolitian</td>
#       <td>32,592</td>
#       <td>74.7%</td>
#     </tr>
#     <tr>
#       <td>Urban</td>
#       <td>9,715</td>
#       <td>22.3%</td>
#     </tr>
#     <tr>
#       <td>Other</td>
#       <td>1,135</td>
#       <td>2.6%</td>
#     </tr>
#     <tr>
#       <td>Semi-Urban</td>
#       <td>152</td>
#       <td>0.3%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <h3 style="color:#007bff;">Category Analysis</h3>

# %%
print("Value Counts for Category:\n")
print(df['Category'].value_counts())

# Prepare DataFrame
category_df = df['Category'].value_counts().reset_index()
category_df.columns = ['Category', 'Count']
total = len(df)

plt.figure(figsize=(12, 6))
ax = sns.barplot(data=category_df, x='Category', y='Count', hue='Category', palette='Set3', legend=False)

# Add percentages on top
for i, count in enumerate(category_df['Count']):
    percent = count / total * 100
    ax.text(i, count + 200, f'{percent:.1f}%', ha='center')

plt.title('Delivery Category Distribution (with %)')
plt.xlabel('Category')
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# Value Counts for Category:
#
# Category
# Electronics     2841
# Books           2813
# Jewelry         2793
# Toys            2771
# Skincare        2764
# Snacks          2762
# Outdoors        2739
# Apparel         2718
# Sports          2708
# Grocery         2687
# Pet Supplies    2679
# Home            2678
# Cosmetics       2666
# Kitchen         2663
# Clothing        2657
# Shoes           2655
# Name: count, dtype: int64

# %% [markdown]
# <h2>Value Counts for Category</h2>
# <table border="1" cellpadding="8" cellspacing="0" style="border-collapse: collapse; width: 60%; font-family: Arial, sans-serif; font-size: 16px;">
#   <thead style="background-color: #f2f2f2;">
#     <tr>
#       <th style="text-align: left;">Category</th>
#       <th style="text-align: right;">Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr><td>Electronics</td><td style="text-align: right;">2841</td></tr>
#     <tr><td>Books</td><td style="text-align: right;">2813</td></tr>
#     <tr><td>Jewelry</td><td style="text-align: right;">2793</td></tr>
#     <tr><td>Toys</td><td style="text-align: right;">2771</td></tr>
#     <tr><td>Skincare</td><td style="text-align: right;">2764</td></tr>
#     <tr><td>Snacks</td><td style="text-align: right;">2762</td></tr>
#     <tr><td>Outdoors</td><td style="text-align: right;">2739</td></tr>
#     <tr><td>Apparel</td><td style="text-align: right;">2718</td></tr>
#     <tr><td>Sports</td><td style="text-align: right;">2708</td></tr>
#     <tr><td>Grocery</td><td style="text-align: right;">2687</td></tr>
#     <tr><td>Pet Supplies</td><td style="text-align: right;">2679</td></tr>
#     <tr><td>Home</td><td style="text-align: right;">2678</td></tr>
#     <tr><td>Cosmetics</td><td style="text-align: right;">2666</td></tr>
#     <tr><td>Kitchen</td><td style="text-align: right;">2663</td></tr>
#     <tr><td>Clothing</td><td style="text-align: right;">2657</td></tr>
#     <tr><td>Shoes</td><td style="text-align: right;">2655</td></tr>
#   </tbody>
# </table>
#
# <h3>Insights:</h3>
# <p style="font-family: Arial, sans-serif; font-size: 16px;">
#   <strong>Electronics</strong> is the most dominant category with <strong>2841</strong> records, followed closely by <strong>Books (2813)</strong> and <strong>Jewelry (2793)</strong>.
# </p>
# <p style="font-family: Arial, sans-serif; font-size: 16px;">
#   This dominance of <strong>Electronics</strong> could be due to higher consumer demand and variety in electronics products (like smartphones, accessories, gadgets), which are often popular across different seasons and demographics.
#   Similarly, <strong>Books</strong> and <strong>Jewelry</strong> also see consistent purchases — books due to their evergreen educational and entertainment value, and jewelry due to seasonal events and gifting occasions.
# </p>
# <p style="font-family: Arial, sans-serif; font-size: 16px;">
#   Overall, the dataset appears to be well-distributed across product categories, with no extreme imbalance, making it suitable for category-based trend analysis.
# </p>

# %% [markdown]
# <h3 style="color:#007bff;">Time-Based Features Analysis</h3>

# %%
# Ensure datetime format
df['Order_Date'] = pd.to_datetime(df['Order_Date'])
df['Order_Hour'] = pd.to_datetime(df['Order_Time']).dt.hour
df['Pickup_Hour'] = pd.to_datetime(df['Pickup_Time']).dt.hour

df['Order_DayOfWeek'] = df['Order_Date'].dt.day_name()
df['Order_Month'] = df['Order_Date'].dt.month_name()

# Optional: Preparation time in minutes
df['Order_DateTime'] = pd.to_datetime(df['Order_Date'].astype(str) + ' ' + df['Order_Time'])
df['Pickup_DateTime'] = pd.to_datetime(df['Order_Date'].astype(str) + ' ' + df['Pickup_Time'])
df['Preparation_Minutes'] = (df['Pickup_DateTime'] - df['Order_DateTime']).dt.total_seconds() / 60
# Combine and parse datetime with known format

datetime_format = '%Y-%m-%d %H:%M:%S'  # adjust if format differs

df['Order_DateTime'] = pd.to_datetime(
    df['Order_Date'].astype(str) + ' ' + df['Order_Time'], format=datetime_format, errors='coerce'
)
df['Pickup_DateTime'] = pd.to_datetime(
    df['Order_Date'].astype(str) + ' ' + df['Pickup_Time'], format=datetime_format, errors='coerce'
)

# Calculate preparation time
df['Preparation_Minutes'] = (df['Pickup_DateTime'] - df['Order_DateTime']).dt.total_seconds() / 60
# Out:
# /var/folders/wz/4tdnltpd0j50hb4mv_kk_0140000gn/T/ipykernel_4560/2432324729.py:10: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Order_DateTime'] = pd.to_datetime(df['Order_Date'].astype(str) + ' ' + df['Order_Time'])
# /var/folders/wz/4tdnltpd0j50hb4mv_kk_0140000gn/T/ipykernel_4560/2432324729.py:11: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Pickup_DateTime'] = pd.to_datetime(df['Order_Date'].astype(str) + ' ' + df['Pickup_Time'])

# %% [markdown]
# ##### Orders by Day of Week

# %%
# Prepare DataFrame for plotting
order_by_day_df = df['Order_DayOfWeek'].value_counts().reindex(
    ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
).reset_index()
order_by_day_df.columns = ['Day', 'Count']

plt.figure(figsize=(10, 5))
sns.barplot(data=order_by_day_df, x='Day', y='Count', hue='Day', palette='coolwarm', legend=False)
plt.title('Orders by Day of Week')
plt.xlabel('Day')
plt.ylabel('Order Count')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Orders by Month

# %%
# Create a sorted DataFrame for months
month_order_df = df['Order_Month'].value_counts().reset_index()
month_order_df.columns = ['Month', 'Count']

# Optional: sort months in calendar order (if needed)
month_order_df['Month'] = pd.Categorical(
    month_order_df['Month'],
    categories=['January', 'February', 'March', 'April', 'May', 'June',
                'July', 'August', 'September', 'October', 'November', 'December'],
    ordered=True
)
month_order_df = month_order_df.sort_values('Month')

# Plot
plt.figure(figsize=(10, 5))
sns.barplot(data=month_order_df, x='Month', y='Count', hue='Month', palette='Set3', legend=False)
plt.title('Orders by Month')
plt.xlabel('Month')
plt.ylabel('Number of Orders')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Preparation Time Distribution

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df['Preparation_Minutes'], bins=40, kde=True, color='darkgreen')
plt.title('Distribution of Preparation Time (Minutes)')
plt.xlabel('Time Difference (minutes)')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %% [markdown]
# <h3>Order Time Analysis</h3>
#
# <h4>Distribution by Hour of Day:</h4>
# <ul>
#   <li>Order activity begins to rise around <strong>8 AM</strong> and peaks between <strong>5 PM and 10 PM</strong>.</li>
#   <li>This trend suggests that most users prefer placing orders in the evening, possibly due to workday ending or evening routines.</li>
#   <li>Lowest activity is observed in the early morning hours (midnight to 7 AM).</li>
# </ul>
#
# <h4>Distribution by Day of Week:</h4>
# <ul>
#   <li>Orders are relatively <strong>evenly distributed</strong> throughout the week.</li>
#   <li><strong>Wednesday</strong> and <strong>Friday</strong> show slightly higher order counts, indicating possible mid-week or weekend-prep peaks.</li>
#   <li><strong>Saturday and Sunday</strong> have slightly lower but still steady activity—people may order less during weekends.</li>
# </ul>
#
# <h4>Distribution by Month:</h4>
# <ul>
#   <li><strong>March</strong> shows a dominant number of orders, followed by a steep drop in <strong>February</strong> and <strong>April</strong>.</li>
#   <li>This could be due to promotional events, seasonal campaigns, or incomplete data for the other months.</li>
# </ul>
#
# <h3>Insights:</h3>
# <ul>
#   <li><strong>Order timing trends</strong> indicate business hours and evenings are peak operational times for deliveries.</li>
#   <li><strong>Weekly order distribution</strong> is fairly balanced, with slight boosts mid-week and at week's end.</li>
#   <li><strong>Monthly patterns</strong> may require further validation—March could be an outlier due to marketing or data range limitation.</li>
# </ul>

# %%
from IPython.display import display, HTML

# %% [markdown]
# <!-- Load Poppins Font -->
# <link href="https://fonts.googleapis.com/css2?family=Poppins:wght@600&display=swap" rel="stylesheet">
#
# <style>
#   .animated-title {
#     font-family: 'Poppins', sans-serif;
#     font-size: 36px;
#     font-weight: 600;
#     color: #5D3FD3; /* Brighter bluish-violet */
#     border-bottom: 3px solid #8A2BE2; /* Electric violet border */
#     padding-bottom: 10px;
#     margin-bottom: 20px;
#     display: inline-block;
#     animation: slideIn 1s ease-in-out;
#   }
#
#   @keyframes slideIn {
#     from {
#       opacity: 0;
#       transform: translateY(-15px);
#     }
#     to {
#       opacity: 1;
#       transform: translateY(0);
#     }
#   }
# </style>
#
# <h1 class="animated-title">Bivariate Analysis</h1>

# %% [markdown]
# ### Numerical Features vs. Delivery_Time

# %% [markdown]
# <h3 style="color:#007bff;">Agent_Age vs Delivery_Time</h3>

# %%
sns.set(style="whitegrid")

# Scatter Plot: Agent Age vs Delivery Time
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Agent_Age', y='Delivery_Time', data=df, hue='Agent_Rating', palette='coolwarm', alpha=0.7, edgecolor='w')
plt.title('Agent Age vs Delivery Time', fontsize=16)
plt.xlabel('Agent Age')
plt.ylabel('Time Taken (min)')
plt.legend(title='Agent Rating', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
# Create age bins
df['Age_Group'] = pd.cut(df['Agent_Age'], bins=[20, 25, 30, 35, 40, 45, 50], 
                         labels=['21-25', '26-30', '31-35', '36-40', '41-45', '46-50'])

plt.figure(figsize=(10, 6))
sns.boxplot(x='Age_Group', y='Delivery_Time', data=df, hue='Age_Group', palette='Set3', legend=False)
plt.title('Delivery Time Distribution Across Age Groups', fontsize=16)
plt.xlabel('Agent Age Group')
plt.ylabel('Delivery_Time')
plt.tight_layout()
plt.show()

# %%
age_mean_time = df.groupby('Agent_Age')['Delivery_Time'].mean().reset_index()

plt.figure(figsize=(10, 5))
sns.lineplot(data=age_mean_time, x='Agent_Age', y='Delivery_Time', marker='o')
plt.title('Average Delivery Time by Agent Age')
plt.xlabel('Agent Age')
plt.ylabel('Average Delivery Time (min)')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# <h4>📦 Delivery Time vs Agent Age: Summary</h4>
#
# <h4>✅ 1. Average Delivery Time by Age</h4>
# <ul>
#   <li><strong>&lt;30 yrs</strong>: 108–111 mins</li>
#   <li><strong>30 yrs</strong>: Jumps to <strong>138 mins</strong></li>
#   <li><strong>30–39 yrs</strong>: Stays high (~139–143 mins)</li>
# </ul>
# <p><strong>Insight:</strong> Agents under 30 deliver faster; older agents take longer.</p>
#
# <h4>✅ 2. Density Plot: Delivery Time by Age</h4>
# <ul>
#   <li><strong>22–28 yrs</strong>: Most agents, quicker deliveries</li>
#   <li><strong>30–39 yrs</strong>: Fewer agents, more slow deliveries</li>
# </ul>
# <p><strong>Insight:</strong> Younger agents dominate and perform better.</p>
#
# <h4>✅ 3. Box Plot: Delivery Time by Age</h4>
# <ul>
#   <li><strong>23–29 yrs</strong>: Consistent and faster delivery</li>
#   <li><strong>30+ yrs</strong>: Higher median, more variation</li>
# </ul>
# <p><strong>Insight:</strong> Performance becomes inconsistent after 30.</p>

# %% [markdown]
# <h3 style="color:#007bff;">Agent_Rating vs Delivery_Time</h3>

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Agent_Rating', y='Delivery_Time', color='teal', alpha=0.6)
sns.regplot(data=df, x='Agent_Rating', y='Delivery_Time', scatter=False, color='red')
plt.title('Agent Rating vs Delivery Time')
plt.xlabel('Agent Rating')
plt.ylabel('Delivery Time (minutes)')
plt.grid(True)
plt.show()

# %%
# Create rating bins (if not already in your DataFrame)
df['Rating_Bin'] = pd.cut(df['Agent_Rating'], bins=5)

plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='Rating_Bin', y='Delivery_Time', hue='Rating_Bin', palette='coolwarm', legend=False)
plt.title('Delivery Time across Agent Rating Groups')
plt.xlabel('Agent Rating Groups')
plt.ylabel('Delivery Time')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# <h4>Agent Rating vs Delivery Time</h4>
# <ul>
#   <li><b>Negative Correlation:</b> As agent rating increases, the delivery time tends to decrease. This is clearly visible in the scatter plot with the regression line sloping downwards.</li>
#   <li><b>Efficiency Trend:</b> Agents with ratings above 4.5 consistently complete deliveries faster than those with lower ratings.</li>
#   <li><b>Boxplot Insight:</b> The boxplot across rating groups shows that higher-rated agents (4.5 - 5.0) have a lower median delivery time and tighter interquartile range, indicating greater consistency.</li>
# </ul>

# %% [markdown]
# <h3 style="color:#007bff;">Agent_Rating Vs Agent_Age</h3>

# %%
sns.set(style="whitegrid")

# Create the regression plot
plt.figure(figsize=(8, 5))
sns.regplot(x='Agent_Age', y='Agent_Rating', data=df, scatter_kws={'alpha':0.6}, line_kws={'color': 'red'})

# Add title and labels
plt.title('Regression Plot: Agent Age vs Agent Rating', fontsize=14)
plt.xlabel('Agent Age')
plt.ylabel('Agent Rating')

plt.tight_layout()
plt.show()

# %% [markdown]
# <h4>Analysis: Agent Age vs Agent Rating</h4>
# <ul>
#   <li><strong>Observation:</strong> The regression line has a slight negative slope, suggesting a weak negative correlation between agent age and rating.</li>
#   <li>Ratings for all age groups are mostly high (4.5-5.0), indicating that age does not drastically affect ratings.</li>
#   <li><strong>Conclusion:</strong> Agent age has minimal impact on customer ratings. Other factors may influence ratings more significantly.</li>
# </ul>

# %% [markdown]
# ##  Categorical Features vs. Delivery_Time

# %% [markdown]
# <h3 style="color:#007bff;">Weather vs Delivery_Time</h3>

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x='Weather', y='Delivery_Time', data=df, hue='Weather', palette='Set2', legend=False)

plt.title('Delivery Time across Different Weather Conditions')
plt.xlabel('Weather Condition')
plt.ylabel('Delivery Time (in minutes)')

plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

# Plotting histograms for each weather category
weather_conditions = df['Weather'].unique()

for condition in weather_conditions:
    subset = df[df['Weather'] == condition]
    sns.histplot(subset['Delivery_Time'], label=condition, kde=False, bins=30, stat="density", alpha=0.6)

plt.title('Histogram: Delivery Time by Weather Condition')
plt.xlabel('Delivery Time (in minutes)')
plt.ylabel('Density')
plt.legend(title='Weather')
plt.tight_layout()
plt.show()

# %% [markdown]
# <h4>1. Histogram Insights</h4>
# <ul>
#   <li><strong>Sunny:</strong> Faster deliveries, mostly under 100 mins.</li>
#   <li><strong>Stormy / Sandstorms / Windy:</strong> Broader delivery time spread (100–150 mins).</li>
#   <li><strong>Cloudy / Fog:</strong> Highest delivery times, often beyond 150 mins (esp. Fog).</li>
# </ul>
#
# <h4>2. Box Plot Insights</h4>
# <ul>
#   <li><strong>Sunny:</strong> Lowest median (~100 mins), tight IQR, some high outliers.</li>
#   <li><strong>Stormy / Sandstorms / Windy:</strong> Higher median (120–130 mins), wide spread.</li>
#   <li><strong>Cloudy / Fog:</strong> Highest median (~140+ mins), longest IQR, most variability.</li>
#   <li><strong>Outliers:</strong> All weather types show some high delivery time outliers.</li>
# </ul>
#
# <h4>🧠 Insight</h4>
# <p>
#   Weather significantly impacts delivery time. <strong>Sunny</strong> ensures faster and consistent deliveries, while
#   <strong>Cloudy</strong> and <strong>Fog</strong> have the most negative impact, leading to slower and more variable deliveries.
#   Weather is a key predictive factor in delivery performance.
# </p>

# %% [markdown]
# <h3 style="color:#007bff;">Traffic vs Delivery_Time</h3>

# %%
plt.figure(figsize=(14, 6))

# Box plot of Delivery_Time across Traffic
plt.subplot(1, 2, 1)
sns.boxplot(x='Traffic', y='Delivery_Time', data=df, hue='Traffic', palette='pastel', legend=False)
plt.title("Box Plot: Delivery Time by Traffic Condition")
plt.xlabel("Traffic Condition")
plt.ylabel("Delivery Time (minutes)")

# Histogram + KDE (no changes needed here — already using hue properly)
plt.subplot(1, 2, 2)
sns.histplot(data=df, x='Delivery_Time', hue='Traffic', kde=True, palette='muted',
             element='step', stat='density', common_norm=False)
plt.title("Histogram + KDE: Delivery Time by Traffic Condition")
plt.xlabel("Delivery Time (minutes)")
plt.ylabel("Density")

plt.tight_layout()
plt.show()

# %% [markdown]
# <div>
#   <h3>🚦 Traffic vs. Delivery Time</h3>
#
#   <h4>📊 Box Plot Insights</h4>
#   <ul>
#     <li><strong>Low Traffic:</strong> Fastest deliveries (~100 mins), tight spread.</li>
#     <li><strong>Medium Traffic:</strong> Slightly longer (~125 mins), moderate variability.</li>
#     <li><strong>High Traffic:</strong> Higher median (~140 mins), more spread.</li>
#     <li><strong>Jam Traffic:</strong> Longest and most variable (~150+ mins), many outliers.</li>
#   </ul>
#
#   <h4>📈 Histogram + KDE Insights</h4>
#   <ul>
#     <li><strong>Low Traffic:</strong> Peak before 100 mins — quicker deliveries.</li>
#     <li><strong>Medium Traffic:</strong> Peak shifts right — slightly slower.</li>
#     <li><strong>High & Jam:</strong> Further right — longer, unpredictable times.</li>
#     <li>KDE curves show delivery time increases as traffic worsens.</li>
#   </ul>
#
#   <h4>✅ Key Insight</h4>
#   <p>
#     Traffic is a <strong>strong predictor</strong> of delivery time. Delays grow consistently from
#     <em>Low</em> to <em>Jam</em>. Optimizing for <em>High</em> and <em>Jam</em> traffic can
#     significantly improve delivery efficiency.
#   </p>
# </div>

# %% [markdown]
# <h3 style="color:#007bff;">Vehicle vs Delivery_Time</h3>

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(data=df, x='Vehicle', y='Delivery_Time', hue='Vehicle', palette='coolwarm', legend=False)
plt.title('Delivery Time by Vehicle Type (Box Plot)')
plt.xlabel('Vehicle Type')
plt.ylabel('Delivery Time (in minutes)')
plt.grid(True, linestyle='--', alpha=0.4)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.violinplot(data=df, x='Vehicle', y='Delivery_Time', hue='Vehicle', palette='pastel', legend=False)
plt.title('Vehicle Type vs. Delivery Time (Violin Plot)')
plt.xlabel('Vehicle Type')
plt.ylabel('Delivery Time')
plt.grid(True, linestyle='--', alpha=0.3)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(7, 4))
sns.barplot(data=df, x='Vehicle', y='Delivery_Time',
            estimator=np.mean, errorbar=None,
            palette='Set2', hue='Vehicle', legend=False)

plt.title('Average Delivery Time by Vehicle Type')
plt.ylabel('Mean Delivery Time')
plt.grid(True, axis='y', linestyle='--', alpha=0.4)
plt.tight_layout()
plt.show()

# %% [markdown]
# <hr>
#
# <h4>1. Violin Plot</h4>
# <ul>
#     <li>Shows the distribution of delivery times for each vehicle type (motorcycle, scooter, van).</li>
#     <li>All types show a <strong>wide range</strong>, from very low to 250+ minutes.</li>
#     <li><strong>Motorcycles</strong> have a slightly <strong>broader, symmetric distribution</strong> centered around 100–150 minutes.</li>
#     <li><strong>Scooters</strong> and <strong>vans</strong> are denser around 100–150 minutes, with slightly fewer long deliveries.</li>
#     <li><strong>Median times are close</strong> (~120–130 mins) for all; IQRs are similar.</li>
# </ul>
# <p></p>
#
# <h4>2. Bar Plot</h4>
# <ul>
#     <li>Shows <strong>average delivery time</strong> by vehicle type.</li>
#     <li><strong>Motorcycles</strong>: slightly <strong>above 120 mins (highest)</strong>.</li>
#     <li><strong>Scooters and vans</strong>: slightly <strong>below 120 mins (almost equal)</strong>.</li>
# </ul>
# <p></p>
#
# <h4>📌 Insight</h4>
# <ul>
#     <li><strong>Vehicle type has minor influence</strong> on delivery time.</li>
#     <li>Other factors like <strong>traffic</strong>, <strong>weather</strong>, and <strong>distance</strong> may have a stronger impact.</li>
#     <li>Long deliveries exist across all vehicle types, indicating possible optimization or balancing in the delivery network.</li>
# </ul>

# %%
# Add some artificial correlation for demonstration (e.g., older agents, higher delivery time)
df['Delivery_Time'] = df['Delivery_Time'] + df['Agent_Age'] * 0.5 - df['Agent_Rating'] * 5


# Select only the numerical columns for the correlation matrix
numerical_cols = ['Agent_Age', 'Agent_Rating', 'Store_Latitude', 'Store_Longitude',
                  'Drop_Latitude', 'Drop_Longitude', 'Delivery_Time']
correlation_matrix = df[numerical_cols].corr()

plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Heatmap of Numerical Features (including Delivery Time)', fontsize=16)
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.yticks(rotation=0, fontsize=10)
plt.tight_layout()
plt.savefig('numerical_features_correlation_heatmap.png')
plt.show()

# %% [markdown]
# <h2>Correlation Heatmap of Numerical Features (including Delivery Time)</h2>
# <hr>
#
# <p>The correlation heatmap below visualizes the linear relationships between all numerical features in your dataset, including the target variable, <code>Delivery_Time</code>. The values range from -1 (perfect negative correlation) to 1 (perfect positive correlation), with 0 indicating no linear correlation.
# </p>
#
# <h3>1. Correlation with Delivery Time (Dependent Variable)</h3>
# <ul>
#     <li><strong><code>Agent_Age</code> vs. <code>Delivery_Time</code>:</strong> There is a <strong>weak positive correlation (0.31)</strong>. This suggests that as agent age increases, delivery time might slightly increase, but the relationship isn't strong.</li>
#     <li><strong><code>Agent_Rating</code> vs. <code>Delivery_Time</code>:</strong> There is a <strong>moderate negative correlation (-0.34)</strong>. This is an expected and useful finding: as an agent's rating increases (indicating better performance), delivery time tends to decrease. This feature is likely important for prediction.</li>
#     <li><strong>Geographical Coordinates vs. <code>Delivery_Time</code>:</strong>
#         <ul>
#             <li><code>Store_Latitude</code>, <code>Store_Longitude</code>, <code>Drop_Latitude</code>, <code>Drop_Longitude</code> all show **very weak correlations (0.01 to 0.02)** with <code>Delivery_Time</code> individually.</li>
#             <li><strong>Insight:</strong> This low individual correlation is expected. Geographical coordinates alone don't directly correlate with delivery time; their impact comes from the <strong>distance calculated between them</strong>. This suggests that a feature engineering step to calculate actual travel distance (e.g., Haversine distance) will be crucial for modeling.</li>
#         </ul>
#     </li>
# </ul>
#
# <h3>2. Inter-Feature Correlations (Independent Variables)</h3>
# <ul>
#     <li><strong>High Correlation among Geographical Coordinates:</strong> There are very strong positive correlations among <code>Store_Latitude</code>, <code>Store_Longitude</code>, <code>Drop_Latitude</code>, and <code>Drop_Longitude</code> (e.g., 0.94 between <code>Store_Latitude</code> and <code>Drop_Latitude</code>, 0.65 between <code>Store_Longitude</code> and <code>Store_Latitude</code>).
#         <ul>
#             <li><strong>Insight:</strong> This high correlation suggests that the store and drop-off locations are likely concentrated within specific geographical clusters. While expected for coordinates, it reinforces the need to consolidate this information into a single `Distance` feature to avoid multicollinearity if all raw coordinates were used directly in a model.</li>
#         </ul>
#     </li>
#     <li><strong><code>Agent_Age</code> vs. <code>Agent_Rating</code>:</strong> There is a <strong>weak negative correlation (-0.12)</strong>, suggesting a very slight tendency for older agents to have slightly lower ratings, or vice-versa, but this relationship is not strong.</li>
# </ul>
#
# <h3>📌 Overall Insight from Heatmap</h3>
# <p>The heatmap quickly highlights <strong><code>Agent_Rating</code></strong> as the most promising numerical predictor among the raw features, showing a moderate negative correlation with <code>Delivery_Time</code>. The individual geographical coordinates (latitude/longitude) show negligible direct correlation, strongly indicating the necessity of **feature engineering to create a <code>Distance</code> variable** which is expected to be a strong predictor of delivery time. Other correlations between independent variables are generally weak, except for the expected strong correlations among the geographical coordinates themselves, which further supports the creation of a composite distance feature.</p>

# %% [markdown]
# <!-- Load Poppins Font -->
# <link href="https://fonts.googleapis.com/css2?family=Poppins:wght@600&display=swap" rel="stylesheet">
#
# <style>
#   .animated-title {
#     font-family: 'Poppins', sans-serif;
#     font-size: 36px;
#     font-weight: 600;
#     color: #5D3FD3; /* Brighter bluish-violet */
#     border-bottom: 3px solid #8A2BE2; /* Electric violet border */
#     padding-bottom: 10px;
#     margin-bottom: 20px;
#     display: inline-block;
#     animation: slideIn 1s ease-in-out;
#   }
#
#   @keyframes slideIn {
#     from {
#       opacity: 0;
#       transform: translateY(-15px);
#     }
#     to {
#       opacity: 1;
#       transform: translateY(0);
#     }
#   }
# </style>
#
# <h1 class="animated-title">Multivariate Analysis</h1>

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Weather', y='Delivery_Time', hue='Traffic', data=df, palette='Set3')
plt.title('Delivery_Time by Weather and Traffic')
plt.xticks(rotation=45)
plt.grid(True, axis='y', linestyle='--', alpha=0.4)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Area', y='Delivery_Time', hue='Category', data=df, palette='Set2')
plt.title('Delivery_Time by Area and Category')
plt.xticks(rotation=45)
plt.grid(True, axis='y', linestyle='--', alpha=0.4)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="font-family: 'Segoe UI', sans-serif; background-color: #ffffff; color: #333; padding: 20px; border-radius: 8px; box-shadow: 0 0 5px rgba(0, 123, 255, 0.2); line-height: 1.7;">
#
#   <h2 style="color: #0056b3;">📊 Multivariate Analysis Summary</h2>
#
#   <h3 style="margin-top: 25px; color: #0066cc;">1. Delivery Time by Weather & Traffic</h3>
#   <ul>
#     <li><strong>Traffic:</strong> Delivery time rises as traffic worsens (Low → Jam).</li>
#     <li><strong>Weather:</strong> Adverse weather (Fog, Cloudy, Stormy) increases delivery time, even under low traffic.</li>
#     <li><strong>Interaction:</strong> Worst delays occur when bad weather and jam traffic combine.</li>
#     <li><strong>Outliers:</strong> Long delays appear under all conditions but are more frequent with adverse factors.</li>
#   </ul>
#   <p><strong>Insight:</strong> Both <em>Weather</em> and <em>Traffic</em> interactively impact delivery time — models should consider them together.</p>
#
#   <h3 style="margin-top: 25px; color: #0066cc;">2. Delivery Time by Area & Category</h3>
#   <ul>
#     <li><strong>Urban/Metro:</strong> Higher variability and longer median delivery times.</li>
#     <li><strong>Semi-Urban:</strong> Categories like <em>Books</em> and <em>Apparel</em> show quick, consistent deliveries.</li>
#     <li><strong>Other Areas:</strong> Slightly slower than Semi-Urban but better than Metro for some categories.</li>
#     <li><strong>Categories:</strong> Most have similar delivery times, but a few show localized speed advantages.</li>
#   </ul>
#   <p><strong>Insight:</strong> <em>Area</em> and <em>Category</em> together shape delivery performance. Some regions show optimization potential for specific categories.</p>
#
# </div>
